# %%
import pandas as pd

# %%
df_1 = pd.read_csv("FossilFuelCombustion.csv")
df_2 = pd.read_csv("FossilFuelCombustionBySector.csv")

# %%
new_df_1 = pd.DataFrame(df_1.values[1:], columns=df_1.iloc[0])
new_df_1 = new_df_1.dropna()
new_df_1
# Out:
# 0    Gas  1990.0  1991.0  1992.0  1993.0  1994.0  1995.0  1996.0  1997.0  \
# 0    CO2  4752.2  4705.9  4801.4  4917.7  4981.7  5037.8  5215.2  5275.8
# 1    CH4    16.9    16.9    17.2    16.5    16.3    16.2    16.5    15.4
# 2    N2O    60.8    62.1    64.8    67.3    69.7    71.5    73.4    75.0
# 3  Total  4829.9  4784.9  4883.4  5001.5  5067.7  5125.5  5305.0  5366.1
#
# 0  1998.0  ...  2013.0  2014.0  2015.0  2016.0  2017.0  2018.0  2019.0  \
# 0  5332.3  ...  5114.8  5172.9  5002.9  4906.3  4845.1  4988.2  4852.6
# 1    14.4  ...    13.0    13.0    12.5    11.8    11.5    12.5    12.7
# 2    76.1  ...    53.5    51.9    47.9    46.5    44.0    42.8    41.2
# 3  5422.8  ...  5181.4  5237.8  5063.4  4964.6  4900.6  5043.4  4906.6
#
# 0  2020.0  2021.0  2022.0
# 0  4341.7  4654.3  4699.4
# 1    10.5    10.6    11.2
# 2    36.7    38.9    41.4
# 3  4388.9  4703.7  4752.0
#
# [4 rows x 34 columns]

# %%
new_df_2 = pd.DataFrame(df_2.values[1:], columns=df_2.iloc[0])
new_df_2 = new_df_2.dropna()
new_df_2
# Out:
# 0        Fuel/Sector    1990    1991    1992    1993    1994    1995    1996  \
# 0               Coal  1719.8  1715.8  1733.0  1798.3  1805.0  1820.4  1905.2
# 1        Residential     3.0     2.4     2.5     2.5     2.0     1.7     1.6
# 2         Commercial    12.0    11.1    11.3    11.3    11.3    11.2    11.6
# 3         Industrial   157.8   154.6   150.3   152.5   153.5   147.2   140.1
# 4     Transportation     NO       NO      NO      NO      NO      NO      NO
# 5     Electric Power  1546.5  1547.2  1568.5  1631.6  1637.9  1659.9  1751.5
# 6   U.S. Territories     0.5     0.5     0.4     0.4     0.4     0.4     0.4
# 7        Natural Gas   998.6  1020.9  1054.3  1081.8  1106.6  1155.0  1176.3
# 8        Residential   237.8   247.3   254.6   268.2   262.9   262.8   284.0
# 9         Commercial   142.0   148.1   152.1   154.9   157.0   164.2   171.1
# 10        Industrial   407.4   413.6   429.3   437.0   438.2   461.5   477.2
# ...
